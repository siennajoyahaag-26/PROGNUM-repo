# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# 2.1
# $$E = h c / \lambda$$

# %% [markdown]
# 2.2
# $$F = G\frac{m_1 m_2}{r^2}$$

# %% [markdown]
# 2.3

# %% [markdown]
# 2.5
# $$\displaystyle\sum_{k=0}^{\infty}\frac{1}{4k^2-1}=\frac{1}{2}$$
#
# $$\int_0^\pi\mathrm{e}^{ix}\mathrm{d}x={}2i$$

# %%
2.12
import math
x= float(input("Enter a value for x: "))
y = float(input("Enter a value for y: "))
a = math.atan2(y,x)
print(a)
if a < -math.pi/2:
    print("In quadrant 3")
elif a < 0:
    print("In quadrant 4")
elif a < (math.pi/2):
    print("In quadrant 1")
elif a < math.pi:
    print("In quadrant 2")
# Out:
# Enter a value for x: 2
# Enter a value for y: 3
# 0.982793723247329
# In quadrant 1

# %%
2.14
X= [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
X.append(0.51)
X.remove(2.12)
print(f"The value at index 6 is: {X[6]}")
print(f"The index of 1.46 is: {X.index(1.46)}")
print(f"X: {X}")
X_slice = X[slice(2,-2,2)]
print(f"Slice:{X_slice}")
print(sum([1,2,3]))
print(f"Sum of slice: {sum(X_slice)}")
# Out:
# The value at index 6 is: 1.97
# The index of 1.46 is: 1
# X: [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# Slice:[1.41, 0.98, 1.97]
# 6
# Sum of slice: 4.359999999999999

# %%
2.15 
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

night1set = set(night1)
night2set = set(night2)
intersection = list((night1set).intersection(night2set))
print(intersection)
if 5 in intersection:
    print("5 is an element of the intersection list")
else: 
    print("5 is not an element of the intersection list")
if 5 in night1set:
    print("5 is in night1")
else:
    print("5 is not in night1")
# Out:
# [0, 1, 2, 3, 4]
# 5 is not an element of the intersection list
# 5 is in night1

# %%
2.19
import numpy
import statistics
random = numpy.random.normal(0.0, 1.4, 100000) # Generating 100000 random numbers
print(random)
print(statistics.stdev(random)) # Printing the standard deviation of the generated data set
# Out:
# [-0.57540279  1.26252151 -1.57112875 ...  0.76997243 -0.54933148
#  -0.17982915]
# 1.3994277008196458

# %%
2.21
i = 3 # Index starts at 3 since 1 and 2 are the first two numbers
n1 = 1
n2 = 2
while i<101: # Up to the 100th term
    f = n1 + n2 # Adding two previous terms to get current fibonacci number
    n1 = n2 # n1 is the smaller term, takes on n2's value
    n2 = f # n2 necomes the current fibonacci number
    i=i+1 
print(f)
# Out:
# 573147844013817084101
