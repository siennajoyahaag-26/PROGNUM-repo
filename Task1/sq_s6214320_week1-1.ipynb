# %% [markdown]
# Answers for Week 1
#
# * Name: Sienna Joya Haag
# * Username: sjhaag
# * Student s-number: S6214320
# * Group: AS1

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
six_factorial=6
six_factorial*=5
six_factorial*=4
six_factorial*=3
six_factorial*=2
print(six_factorial)
# Out:
# 720

# %%
from scipy.constants import h
f=2.42e28
photon_energy=h*f
print(photon_energy)
# Out:
# 1.6035089763e-05

# %%
from scipy.constants import G
massmoon=7.342e22
massearth=5.9722e24
r=385000.6e3
force=G*massmoon*massearth/(r**2)
print(force)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# ![Screenshot%20from%202026-02-11%2016-11-30.png](attachment:Screenshot%20from%202026-02-11%2016-11-30.png)

# %% [markdown]
# ![1.10.png](attachment:1.10.png)

# %% [markdown]
# ![1.11.png](attachment:1.11.png)
